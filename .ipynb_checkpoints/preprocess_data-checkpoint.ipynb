# %%
import tensorflow as tf
import numpy as np

# %%
Null_TAG = 'None'
P_TAG_b = 'Pb'  # beginning of participant phrase
P_TAG_m = 'Pm'  # middle/end of participant phrase

# %%
abs_path = 'PICO-annotations/batch5k/0074f5e102cf4409ac07f6209dd30144/20957980.txt'
ann_path = 'PICO-annotations/batch5k/0074f5e102cf4409ac07f6209dd30144/20957980_gold.ann'

abs_file = open(abs_path, 'r');
file_text = abs_file.read();

print file_text

ann_file = open(ann_path, 'r');
ann_file = ann_file.read();

ann_list = ann_file.split();
part_list = [];
for i in range(1, len(ann_list), 2):
    part_list.append((int(ann_list[i]), int(ann_list[i+1])))

for participant_indices in part_list:
    start = participant_indices[0]
    end = participant_indices[1]
    print start
    print end
    print file_text[start:end]
# Out:
# Ipilimumab efficacy and safety in patients with advanced melanoma: a retrospective analysis of HLA subtype from four trials.
#
# Ipilimumab is a fully human, monoclonal antibody that blocks cytotoxic T-lymphocyte antigen-4 to potentiate an antitumor T-cell response. This agent improved overall survival in a phase III trial in previously treated patients with advanced melanoma. Because the mechanism of action for ipilimumab is thought to be HLA independent, most trials enrolled patients without regard to HLA subtype. However, enrollment in the phase III trial was restricted to class-I HLA-A*0201-positive patients because two of the three arms contained an HLA-A*0201-restricted gp100 vaccine. HLA typing was also performed prospectively in several phase II trials and was available for 93.5% of patients. In this retrospective analysis, pooled efficacy and safety data are presented according to HLA-A*0201 status and dose from pretreated patients randomized to 0.3, 3, or 10 mg/kg ipilimumab in four phase II trials. Median overall survival (OS) was similar for the 187 HLA-A*0201-positive [9.3 months, 95% CI (confidence interval) 7.4-11.5] and 266 HLA-A*0201-negative patients [11.4 months, 95% CI 9.3-15.1] randomized to ipilimumab at all doses across the four phase II trials. These data are comparable to the OS for the 137 HLA-A*0201-positive patients randomized to ipilimumab in the phase III study [10.1 months, 95% CI 8.0-13.8]. Ipilimumab-induced adverse events and immune-related adverse events (skin, gastrointestinal, hepatic, other) also occurred at similar frequencies among patients in the phase II and III trials, regardless of HLA-A*0201 status. These findings support the hypothesis that ipilimumab-treated patients with advanced melanoma have similar outcomes regardless of their HLA-A*0201 status.
#
#
# 24
# 65
# safety in patients with advanced melanoma
# 322
# 375
# in previously treated patients with advanced melanoma
# 470
# 517
# enrolled patients without regard to HLA subtype
# 529
# 695
# nrollment in the phase III trial was restricted to class-I HLA-A*0201-positive patients because two of the three arms contained an HLA-A*0201-restricted gp100 vaccine
# 697
# 808
# HLA typing was also performed prospectively in several phase II trials and was available for 93.5% of patients.
# 900
# 1020
# HLA-A*0201 status and dose from pretreated patients randomized to 0.3, 3, or 10 mg/kg ipilimumab in four phase II trials
# 1330
# 1410
# 137 HLA-A*0201-positive patients randomized to ipilimumab in the phase III study

# %%
def annotate_abstract(abstract_path, gold_annotation_path):
    abs_file = open(abs_path, 'r');
    file_text = abs_file.read();

    ann_file = open(ann_path, 'r');
    ann_file = ann_file.read();

    ann_list = ann_file.split();
    part_list = [];
    for i in range(1, len(ann_list), 2):
        part_list.append((int(ann_list[i]), int(ann_list[i+1])))


    word_list = file_text.split(); # [word1, word2, word] no spaces
    tag_list = []
    index = 0; # changed from -1
    ann_index = 0
    ann_start = part_list[ann_index][0]
    ann_end = part_list[ann_index][1]
    in_phrase = False
    sentance_start_ind = []

    for word_ind in range(len(words_list)):
        word = word_list[word_ind]
        index += len(word) + 1;
        if not in_phrase:
            # looking for start of participant phrase
            if (ann_start < index):
                # we found first word in this participant segment
                tag_list.append(P_TAG_b)
                in_phrase = True
            else:
                tag_list.append(Null_TAG)          
        else:
            tag_list.append(P_TAG_m)
            # in the participant phrase, looking for its end
            if (ann_end <= index):
                # we found the last word in the participant segment
                ann_index += 1
                if (ann_index == len(part_list)):
                    ann_start = np.inf
                    ann_end = np.inf
                else:
                    ann_start = part_list[ann_index][0]
                    ann_end = part_list[ann_index][1]
                in_phrase = False

        if word[-1] == ".":
            sentance_start_ind = word_ind

# %%
abs_path = 'PICO-annotations/batch5k/0074f5e102cf4409ac07f6209dd30144/20957980.txt'
ann_path = 'PICO-annotations/batch5k/0074f5e102cf4409ac07f6209dd30144/20957980_gold.ann'
annotate_abstract(abs_path, ann_path)
# Out:
# ['Ipilimumab', 'efficacy', 'and', 'safety', 'in', 'patients', 'with', 'advanced', 'melanoma:', 'a', 'retrospective', 'analysis', 'of', 'HLA', 'subtype', 'from', 'four', 'trials.', 'Ipilimumab', 'is', 'a', 'fully', 'human,', 'monoclonal', 'antibody', 'that', 'blocks', 'cytotoxic', 'T-lymphocyte', 'antigen-4', 'to', 'potentiate', 'an', 'antitumor', 'T-cell', 'response.', 'This', 'agent', 'improved', 'overall', 'survival', 'in', 'a', 'phase', 'III', 'trial', 'in', 'previously', 'treated', 'patients', 'with', 'advanced', 'melanoma.', 'Because', 'the', 'mechanism', 'of', 'action', 'for', 'ipilimumab', 'is', 'thought', 'to', 'be', 'HLA', 'independent,', 'most', 'trials', 'enrolled', 'patients', 'without', 'regard', 'to', 'HLA', 'subtype.', 'However,', 'enrollment', 'in', 'the', 'phase', 'III', 'trial', 'was', 'restricted', 'to', 'class-I', 'HLA-A*0201-positive', 'patients', 'because', 'two', 'of', 'the', 'three', 'arms', 'contained', 'an', 'HLA-A*0201-restricted', 'gp100', 'vaccine.', 'HLA', 'typing', 'was', 'also', 'performed', 'prospectively', 'in', 'several', 'phase', 'II', 'trials', 'and', 'was', 'available', 'for', '93.5%', 'of', 'patients.', 'In', 'this', 'retrospective', 'analysis,', 'pooled', 'efficacy', 'and', 'safety', 'data', 'are', 'presented', 'according', 'to', 'HLA-A*0201', 'status', 'and', 'dose', 'from', 'pretreated', 'patients', 'randomized', 'to', '0.3,', '3,', 'or', '10', 'mg/kg', 'ipilimumab', 'in', 'four', 'phase', 'II', 'trials.', 'Median', 'overall', 'survival', '(OS)', 'was', 'similar', 'for', 'the', '187', 'HLA-A*0201-positive', '[9.3', 'months,', '95%', 'CI', '(confidence', 'interval)', '7.4-11.5]', 'and', '266', 'HLA-A*0201-negative', 'patients', '[11.4', 'months,', '95%', 'CI', '9.3-15.1]', 'randomized', 'to', 'ipilimumab', 'at', 'all', 'doses', 'across', 'the', 'four', 'phase', 'II', 'trials.', 'These', 'data', 'are', 'comparable', 'to', 'the', 'OS', 'for', 'the', '137', 'HLA-A*0201-positive', 'patients', 'randomized', 'to', 'ipilimumab', 'in', 'the', 'phase', 'III', 'study', '[10.1', 'months,', '95%', 'CI', '8.0-13.8].', 'Ipilimumab-induced', 'adverse', 'events', 'and', 'immune-related', 'adverse', 'events', '(skin,', 'gastrointestinal,', 'hepatic,', 'other)', 'also', 'occurred', 'at', 'similar', 'frequencies', 'among', 'patients', 'in', 'the', 'phase', 'II', 'and', 'III', 'trials,', 'regardless', 'of', 'HLA-A*0201', 'status.', 'These', 'findings', 'support', 'the', 'hypothesis', 'that', 'ipilimumab-treated', 'patients', 'with', 'advanced', 'melanoma', 'have', 'similar', 'outcomes', 'regardless', 'of', 'their', 'HLA-A*0201', 'status.']
# ['None', 'None', 'None', 'Pb', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Pb', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Pb', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'None', 'Pb', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pb', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Pb', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'Pb', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'Pm', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
# Ipilimumab :  None
# efficacy :  None
# and :  None
# safety :  Pb
# in :  Pm
# patients :  Pm
# with :  Pm
# advanced :  Pm
# melanoma: :  Pm
# a :  None
# retrospective :  None
# analysis :  None
# of :  None
# HLA :  None
# subtype :  None
# from :  None
# four :  None
# trials. :  None
# Ipilimumab :  None
# is :  None
# a :  None
# fully :  None
# human, :  None
# monoclonal :  None
# antibody :  None
# that :  None
# blocks :  None
# cytotoxic :  None
# T-lymphocyte :  None
# antigen-4 :  None
# to :  None
# potentiate :  None
# an :  None
# antitumor :  None
# T-cell :  None
# response. :  None
# This :  None
# agent :  None
# improved :  None
# overall :  None
# survival :  None
# in :  None
# a :  None
# phase :  None
# III :  None
# trial :  None
# in :  Pb
# previously :  Pm
# treated :  Pm
# patients :  Pm
# with :  Pm
# advanced :  Pm
# melanoma. :  Pm
# Because :  None
# the :  None
# mechanism :  None
# of :  None
# action :  None
# for :  None
# ipilimumab :  None
# is :  None
# thought :  None
# to :  None
# be :  None
# HLA :  None
# independent, :  None
# most :  None
# trials :  None
# enrolled :  Pb
# patients :  Pm
# without :  Pm
# regard :  Pm
# to :  Pm
# HLA :  Pm
# subtype. :  Pm
# However, :  None
# enrollment :  Pb
# in :  Pm
# the :  Pm
# phase :  Pm
# III :  Pm
# trial :  Pm
# was :  Pm
# restricted :  Pm
# to :  Pm
# class-I :  Pm
# HLA-A*0201-positive :  Pm
# patients :  Pm
# because :  Pm
# two :  Pm
# of :  Pm
# the :  Pm
# three :  Pm
# arms :  Pm
# contained :  Pm
# an :  Pm
# HLA-A*0201-restricted :  Pm
# gp100 :  Pm
# vaccine. :  Pm
# HLA :  Pb
# typing :  Pm
# was :  Pm
# also :  Pm
# performed :  Pm
# prospectively :  Pm
# in :  Pm
# several :  Pm
# phase :  Pm
# II :  Pm
# trials :  Pm
# and :  Pm
# was :  Pm
# available :  Pm
# for :  Pm
# 93.5% :  Pm
# of :  Pm
# patients. :  Pm
# In :  None
# this :  None
# retrospective :  None
# analysis, :  None
# pooled :  None
# efficacy :  None
# and :  None
# safety :  None
# data :  None
# are :  None
# presented :  None
# according :  None
# to :  None
# HLA-A*0201 :  Pb
# status :  Pm
# and :  Pm
# dose :  Pm
# from :  Pm
# pretreated :  Pm
# patients :  Pm
# randomized :  Pm
# to :  Pm
# 0.3, :  Pm
# 3, :  Pm
# or :  Pm
# 10 :  Pm
# mg/kg :  Pm
# ipilimumab :  Pm
# in :  Pm
# four :  Pm
# phase :  Pm
# II :  Pm
# trials. :  Pm
# Median :  None
# overall :  None
# survival :  None
# (OS) :  None
# was :  None
# similar :  None
# for :  None
# the :  None
# 187 :  None
# HLA-A*0201-positive :  None
# [9.3 :  None
# months, :  None
# 95% :  None
# CI :  None
# (confidence :  None
# interval) :  None
# 7.4-11.5] :  None
# and :  None
# 266 :  None
# HLA-A*0201-negative :  None
# patients :  None
# [11.4 :  None
# months, :  None
# 95% :  None
# CI :  None
# 9.3-15.1] :  None
# randomized :  None
# to :  None
# ipilimumab :  None
# at :  None
# all :  None
# doses :  None
# across :  None
# the :  None
# four :  None
# phase :  None
# II :  None
# trials. :  None
# These :  None
# data :  None
# are :  None
# comparable :  None
# to :  None
# the :  None
# OS :  None
# for :  None
# the :  None
# 137 :  Pb
# HLA-A*0201-positive :  Pm
# patients :  Pm
# randomized :  Pm
# to :  Pm
# ipilimumab :  Pm
# in :  Pm
# the :  Pm
# phase :  Pm
# III :  Pm
# study :  Pm
# [10.1 :  None
# months, :  None
# 95% :  None
# CI :  None
# 8.0-13.8]. :  None
# Ipilimumab-induced :  None
# adverse :  None
# events :  None
# and :  None
# immune-related :  None
# adverse :  None
# events :  None
# (skin, :  None
# gastrointestinal, :  None
# hepatic, :  None
# other) :  None
# also :  None
# occurred :  None
# at :  None
# similar :  None
# frequencies :  None
# among :  None
# patients :  None
# in :  None
# the :  None
# phase :  None
# II :  None
# and :  None
# III :  None
# trials, :  None
# regardless :  None
# of :  None
# HLA-A*0201 :  None
# status. :  None
# These :  None
# findings :  None
# support :  None
# the :  None
# hypothesis :  None
# that :  None
# ipilimumab-treated :  None
# patients :  None
# with :  None
# advanced :  None
# melanoma :  None
# have :  None
# similar :  None
# outcomes :  None
# regardless :  None
# of :  None
# their :  None
# HLA-A*0201 :  None
# status. :  None

# %%
# CURRENTLY ASSUMES: 
def read_file(abstract_path, gold_annotation_path=None):    
    abstract_file = open(abstract_path, 'r');
    file_text = f.readlines();
    
    
    line_ids = file_text[0::2]
    sentances = file_text[1::2]

    split_s = np.array([line.replace('_', ' ').split() for line in sentances])

    words = np.array([arr[0::2] for arr in split_s])
    tags = np.array([arr[1::2] for arr in split_s])
    
    return [line_ids, words, tags]
