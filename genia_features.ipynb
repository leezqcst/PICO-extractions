# %%
from geniatagger import GeniaTagger
from preprocess_data import get_all_data

# %%
# Directory for geniatagger
genia_directory = 'geniatagger-3.0.2/geniatagger'

tagger = GeniaTagger(genia_directory)

# %%
# Get all data
# Format of word_array: [[word1, word2, ...], ...]
word_array, tag_array = get_all_data()

# Combine all words in the same abstract into one text
abstracts = [' '.join(abstract_words) for abstract_words in word_array]

# %%
# Print elements of a list with spaces
# Element l[i] is padded to have length space[i]
def print_with_spaces(l, spaces):
    # This pads strings to be of space length and aligned left
    formatter = lambda space: '{:' + str(space) + '}'
    
    print ''.join([formatter(space).format(string) for string, space in zip(l, spaces)])

# %%
DEBUG = False

'''
Clean up genia tags
Format: [[feature 1, feature 2, ...], ...]
[feature 1, feature 2, ...] are features of each word

Features: word, base form, POS, chunk, IOB, named entity,
whether word inside parentheses.

Result must be of length length.
'''
def clean_tags(genia_tags, length):
    cleaned_tags = []
    
    # Keep track of whether word is inside parantheses
    inside_paren = False
    
    for word, base_form, pos, chunk, named_entity in genia_tags:
        # ';' has POS ':'
        if word == pos or pos == ':' or pos == '(' or pos == ')' or word == '%':
            # This means the word is puctuation, parentheses, etc.,
            # so we do not make features for it.
            if pos == '(':
                inside_paren = True
            elif pos == ')':
                inside_paren = False
            elif len(word) > 1 and word not in ['``',  '\'\'', '--', 'TO', '...']:
                # This shouldn't happen
                raise ValueError('Unidentified word: ' + word)
            continue
        
        # Now build tags for word
        word_tags = []
        
        word_tags.append(word)
        word_tags.append(base_form)
        word_tags.append(pos)
        
        # Strip out IOB from chunk
        if chunk == 'O':
            word_tags.append(chunk)
        elif len(chunk) > 2:
            word_tags.append(chunk[2:])
        else:
            raise ValueError('Unidentified chunk: ' + chunk)
        
        # Get IOB
        iob = chunk[0]
        if iob == 'O' or iob == 'I' or iob == 'B':
            word_tags.append(iob)
        else:
            raise ValueError('Unidentified chunk:s ' + chunk)
        
        # Strip out IOB from named_entity
        if named_entity == 'O':
            word_tags.append(named_entity)
        elif len(named_entity) > 2:
            word_tags.append(named_entity[2:])
        else:
            raise ValueError('Unidentified named entity: ' + named_entity)
        
        word_tags.append(str(inside_paren))
        
        cleaned_tags.append(word_tags)
    
    for word_tags in cleaned_tags:
                print_with_spaces(word_tags, [25, 25, 5, 5, 5, 10, 5])
    if len(cleaned_tags) != length:
        raise ValueError('There are ' + str(len(cleaned_tags)) +
                         ' tags but there should be ' + str(length))
    
    return cleaned_tags

if DEBUG:
    for abstract, words in zip(abstracts, word_array):
        if abstract.startswith('Association of efavirenz'):
            print abstract
            genia_tags = tagger.parse(abstract)
            cleaned_tags = clean_tags(genia_tags, len(words))
            
            for word_tags in genia_tags:
                print_with_spaces(word_tags, [25, 25, 5, 10, 5])
            for word_tags in cleaned_tags:
                print_with_spaces(word_tags, [25, 25, 5, 5, 5, 10, 5])

# %%
DEBUG = False

# Number of words on each side whose features we take into account
num_surrounding = 4

# Placeholders for out-of-bound indices
start_token = 'START'
stop_token = 'STOP'

'''
Get features from cleaned tags
Same format as cleaned tags
'''
def tags2features(cleaned_tags):
    # Features for whole abstract
    abstract_features = []
    
    for i in range(len(cleaned_tags)):
        word, base_form, pos, chunk, iob, named_entity, inside_paren = cleaned_tags[i]

        word_features = []
            
        '''Features based on the word itself'''
            
        # Feature: POS tag
        word_features.append(pos)
        # Feature: whether word is inside parentheses
        word_features.append(str(inside_paren))

        '''Features based on the phrase containing the word'''
            
        # Feature: type of phrase containing the word
        word_features.append(chunk)
        # Feature: named entity of the word, if any
        word_features.append(named_entity)

        # Feature: whether word is the beginning of its phrase
        word_features.append(str(iob == 'B'))

        # Feature: whether word is the last of its phrase
        # IOB must be I or B and the next IOB must not be I
        if (iob == 'I' or iob == 'B') and \
        (i == len(cleaned_tags)-1 or cleaned_tags[i+1][4] != 'I'):
            word_features.append('True')
        else:
            word_features.append('False')
            
        '''Features based on surrounding words'''
            
        for offset in range(-num_surrounding, num_surrounding + 1):
            if offset != 0:
                new_index = i + offset
                if new_index < 0:
                    # Out of bound to the left
                    word_features.append(start_token)
                    word_features.append(start_token)
                    word_features.append(start_token)
                elif new_index >= len(cleaned_tags):
                    # Out of bound to the right
                    word_features.append(stop_token)
                    word_features.append(stop_token)
                    word_features.append(stop_token)
                else:
                    # Features: POS tags of surrounding words
                    new_pos = cleaned_tags[new_index][2]
                    word_features.append(new_pos)
                        
                    # Features: named entity of surrounding words, if any
                    new_entity = cleaned_tags[new_index][5]
                    word_features.append(new_entity)
            
                    # Features: whether surrounding words are in the same phrase as this word
                    start = min(new_index, i)
                    stop = max(new_index, i)
                    
                    in_same_phrase = True
                    
                    # Check that IOBs from start+1 to stop are all I's
                    for j in range(start+1, stop+1):
                        if cleaned_tags[j][4] != 'I':
                            in_same_phrase = False
                    
                    word_features.append(str(in_same_phrase))
                    
        abstract_features.append(word_features)
    
    return abstract_features

if DEBUG:
    for abstract, words in zip(abstracts, word_array):
        if abstract.startswith('Association of efavirenz'):
            genia_tags = tagger.parse(abstract)
            cleaned_tags = clean_tags(genia_tags, len(words))
            abstract_features = tags2features(cleaned_tags)
            
            for word_tags in cleaned_tags:
                print_with_spaces(word_tags, [25, 25, 5, 5, 5, 10, 5])
            for word_tags in abstract_features:
                print_with_spaces(word_tags, [4, 6, 4, 10, 6, 6] + [6, 10, 6]*24)

# %%
DEBUG = False

DISPLAY = True

'''
Get features from a list of abstracts
Format: [abstract features 1, abstract features 2, ...]
abstract features i = [word features 1, word features 2, ...]
word features i = [feature 1, feature 2, ...]

Length of abstract features i must match length_list[i]
'''
def abstracts2features(abstract_list, length_list):
    # Features of all abstracts
    all_abstracts_features = []
    
    for i in range(len(abstract_list)):
        abstract = abstract_list[i]
        
        if DEBUG:
            if not abstract.startswith('Association of efavirenz'):
                continue
            print abstract
        
        if DISPLAY:
            # Print progress
            print '\r{0}: {1}'.format(i, abstract[:30]),
    
        # Get tags from genia tagger
        # Format: [(Association, Association, NN, B-NP, O), ...]
        # Visualization here: http://nactem7.mib.man.ac.uk/geniatagger/
        genia_tags = tagger.parse(abstract)

        '''Step 1: Clean up genia tags'''

        cleaned_tags = clean_tags(genia_tags, length_list[i])

        '''Step 2: Get features from these tags'''

        abstract_features = tags2features(cleaned_tags)
                
        all_abstracts_features.append(abstract_features)
        
    return all_abstracts_features

if DEBUG:
    lengths = [len(words) for words in word_array]
    
    features = abstracts2features(abstracts, lengths)
    print features

# %%
lengths = [len(words) for words in word_array]

all_features = abstracts2features(abstracts, lengths)
# Out:
# 0: Ipilimumab efficacy and safety Ipilimumab               Ipilimumab               NN   NP   B    O         False
# efficacy                 efficacy                 NN   NP   I    O         False
# and                      and                      CC   O    O    O         False
# safety                   safety                   NN   NP   B    O         False
# in                       in                       IN   PP   B    O         False
# patients                 patient                  NNS  NP   B    O         False
# with                     with                     IN   PP   B    O         False
# advanced                 advance                  VBN  NP   B    O         False
# melanoma                 melanoma                 NN   NP   I    O         False
# a                        a                        DT   NP   B    O         False
# retrospective            retrospective            JJ   NP   I    O         False
# analysis                 analysis                 NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# HLA                      HLA                      NN   NP   B    O         False
# subtype                  subtype                  NN   NP   I    O         False
# from                     from                     IN   PP   B    O         False
# four                     four                     CD   NP   B    O         False
# trials.                  trials.                  NN   NP   I    protein   False
# Ipilimumab               Ipilimumab               NN   NP   I    protein   False
# is                       be                       VBZ  VP   B    O         False
# a                        a                        DT   NP   B    O         False
# fully                    fully                    RB   NP   I    O         False
# human                    human                    JJ   NP   I    O         False
# monoclonal               monoclonal               JJ   NP   I    protein   False
# antibody                 antibody                 NN   NP   I    protein   False
# that                     that                     WDT  NP   B    O         False
# blocks                   block                    VBZ  VP   B    O         False
# cytotoxic                cytotoxic                JJ   NP   B    protein   False
# T-lymphocyte             T-lymphocyte             NN   NP   I    protein   False
# antigen-4                antigen-4                NN   NP   I    protein   False
# to                       to                       TO   VP   B    O         False
# potentiate               potentiate               VB   VP   I    O         False
# an                       an                       DT   NP   B    O         False
# antitumor                antitumor                JJ   NP   I    O         False
# T-cell                   T-cell                   NN   NP   I    O         False
# response.                response.                NN   NP   I    O         False
# This                     This                     DT   NP   B    O         False
# agent                    agent                    NN   NP   I    O         False
# improved                 improve                  VBD  VP   B    O         False
# overall                  overall                  JJ   NP   B    O         False
# survival                 survival                 NN   NP   I    O         False
# in                       in                       IN   PP   B    O         False
# a                        a                        DT   NP   B    O         False
# phase                    phase                    NN   NP   I    O         False
# III                      III                      CD   NP   I    O         False
# trial                    trial                    NN   NP   I    O         False
# in                       in                       IN   PP   B    O         False
# previously               previously               RB   NP   B    O         False
# treated                  treat                    VBN  NP   I    O         False
# patients                 patient                  NNS  NP   I    O         False
# with                     with                     IN   PP   B    O         False
# advanced                 advance                  VBN  NP   B    O         False
# melanoma.                melanoma.                NN   NP   I    O         False
# Because                  Because                  IN   SBAR B    O         False
# the                      the                      DT   NP   B    O         False
# mechanism                mechanism                NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# action                   action                   NN   NP   B    O         False
# for                      for                      IN   PP   B    O         False
# ipilimumab               ipilimumab               NN   NP   B    protein   False
# is                       be                       VBZ  VP   B    O         False
# thought                  think                    VBN  VP   I    O         False
# to                       to                       TO   VP   I    O         False
# be                       be                       VB   VP   I    O         False
# HLA                      HLA                      NN   NP   B    O         False
# independent              independent              JJ   ADJP B    O         False
# most                     most                     JJS  NP   B    O         False
# trials                   trial                    NNS  NP   I    O         False
# enrolled                 enrol                    VBD  VP   B    O         False
# patients                 patient                  NNS  NP   B    O         False
# without                  without                  IN   PP   B    O         False
# regard                   regard                   NN   NP   B    O         False
# to                       to                       TO   PP   B    O         False
# HLA                      HLA                      NN   NP   B    O         False
# subtype.                 subtype.                 NN   NP   I    O         False
# However                  However                  RB   ADVP B    O         False
# enrollment               enrollment               NN   NP   B    O         False
# in                       in                       IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# phase                    phase                    NN   NP   I    O         False
# III                      III                      CD   NP   I    O         False
# trial                    trial                    NN   NP   I    O         False
# was                      be                       VBD  VP   B    O         False
# restricted               restricted               JJ   ADJP B    O         False
# to                       to                       TO   PP   B    O         False
# class-I                  class-I                  NN   NP   B    O         False
# HLA-A*0201-positive      HLA-A*0201-positive      JJ   NP   I    O         False
# patients                 patient                  NNS  NP   I    O         False
# because                  because                  IN   SBAR B    O         False
# two                      two                      CD   NP   B    O         False
# of                       of                       IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# three                    three                    CD   NP   I    O         False
# arms                     arm                      NNS  NP   I    O         False
# contained                contain                  VBD  VP   B    O         False
# an                       an                       DT   NP   B    O         False
# HLA-A*0201-restricted    HLA-A*0201-restricted    JJ   NP   I    O         False
# gp100                    gp100                    NN   NP   I    O         False
# vaccine.                 vaccine.                 NN   NP   I    O         False
# HLA                      HLA                      NN   NP   I    O         False
# typing                   typing                   NN   NP   I    O         False
# was                      be                       VBD  VP   B    O         False
# also                     also                     RB   VP   I    O         False
# performed                perform                  VBN  VP   I    O         False
# prospectively            prospectively            RB   ADVP B    O         False
# in                       in                       IN   PP   B    O         False
# several                  several                  JJ   NP   B    O         False
# phase                    phase                    NN   NP   I    O         False
# II                       II                       CD   NP   B    O         False
# trials                   trial                    NNS  NP   I    O         False
# and                      and                      CC   O    O    O         False
# was                      be                       VBD  VP   B    O         False
# available                available                JJ   ADJP B    O         False
# for                      for                      IN   PP   B    O         False
# 93.5                     93.5                     CD   NP   B    O         False
# of                       of                       IN   PP   B    O         False
# patients.                patients.                NN   NP   B    O         False
# In                       In                       IN   PP   B    O         False
# this                     this                     DT   NP   B    O         False
# retrospective            retrospective            JJ   NP   I    O         False
# analysis                 analysis                 NN   NP   I    O         False
# pooled                   pool                     VBD  VP   B    O         False
# efficacy                 efficacy                 NN   NP   B    O         False
# and                      and                      CC   NP   I    O         False
# safety                   safety                   NN   NP   I    O         False
# data                     datum                    NNS  NP   I    O         False
# are                      be                       VBP  VP   B    O         False
# presented                present                  VBN  VP   I    O         False
# according                accord                   VBG  PP   B    O         False
# to                       to                       TO   PP   B    O         False
# HLA-A*0201               HLA-A*0201               NN   NP   B    O         False
# status                   status                   NN   NP   I    O         False
# and                      and                      CC   O    O    O         False
# dose                     dose                     NN   NP   B    O         False
# from                     from                     IN   PP   B    O         False
# pretreated               pretreate                VBN  NP   B    O         False
# patients                 patient                  NNS  NP   I    O         False
# randomized               randomize                VBD  VP   B    O         False
# to                       to                       TO   PP   B    O         False
# 0.3                      0.3                      CD   NP   B    O         False
# 3                        3                        CD   NP   I    O         False
# or                       or                       CC   O    O    O         False
# 10                       10                       CD   NP   B    O         False
# mg/kg                    mg/kg                    NN   NP   I    O         False
# ipilimumab               ipilimumab               NN   NP   I    O         False
# in                       in                       IN   PP   B    O         False
# four                     four                     CD   NP   B    O         False
# phase                    phase                    NN   NP   I    O         False
# II                       II                       CD   NP   I    O         False
# trials.                  trials.                  NN   NP   I    O         False
# Median                   Median                   JJ   NP   I    O         False
# overall                  overall                  JJ   NP   I    O         False
# survival                 survival                 NN   NP   I    O         False
# OS                       OS                       NN   NP   B    O         True
# was                      be                       VBD  VP   B    O         False
# similar                  similar                  JJ   ADJP B    O         False
# for                      for                      IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# 187                      187                      CD   NP   I    O         False
# HLA-A*0201-positive      HLA-A*0201-positive      JJ   NP   I    O         False
# 9.3                      9.3                      CD   NP   B    O         True
# months                   month                    NNS  NP   I    O         True
# 95                       95                       CD   NP   B    O         True
# CI                       CI                       NN   NP   I    O         True
# confidence               confidence               NN   NP   B    O         True
# interval                 interval                 NN   NP   I    O         True
# 7.4-11.5                 7.4-11.5                 CD   NP   B    O         False
# and                      and                      CC   O    O    O         False
# 266                      266                      CD   NP   B    O         False
# HLA-A*0201-negative      HLA-A*0201-negative      JJ   NP   I    O         False
# patients                 patient                  NNS  NP   I    O         False
# 11.4                     11.4                     CD   NP   B    O         True
# months                   month                    NNS  NP   I    O         True
# 95                       95                       CD   NP   B    O         True
# CI                       CI                       NN   NP   I    O         True
# 9.3-15.1                 9.3-15.1                 CD   NP   I    O         True
# randomized               randomize                VBN  VP   B    O         False
# to                       to                       TO   VP   I    O         False
# ipilimumab               ipilimumab               VB   VP   I    O         False
# at                       at                       IN   PP   B    O         False
# all                      all                      DT   NP   B    O         False
# doses                    dose                     NNS  NP   I    O         False
# across                   across                   IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# four                     four                     CD   NP   I    O         False
# phase                    phase                    NN   NP   I    O         False
# II                       II                       CD   NP   I    O         False
# trials.                  trials.                  NN   NP   I    O         False
# These                    These                    DT   NP   B    O         False
# data                     datum                    NNS  NP   I    O         False
# are                      be                       VBP  VP   B    O         False
# comparable               comparable               JJ   ADJP B    O         False
# to                       to                       TO   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# OS                       OS                       NN   NP   I    O         False
# for                      for                      IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# 137                      137                      CD   NP   I    O         False
# HLA-A*0201-positive      HLA-A*0201-positive      JJ   NP   I    O         False
# patients                 patient                  NNS  NP   I    O         False
# randomized               randomize                VBN  VP   B    O         False
# to                       to                       TO   VP   B    O         False
# ipilimumab               ipilimumab               VB   VP   I    O         False
# in                       in                       IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# phase                    phase                    NN   NP   I    O         False
# III                      III                      CD   NP   I    O         False
# study                    study                    NN   NP   I    O         False
# 10.1                     10.1                     CD   NP   B    O         True
# months                   month                    NNS  NP   I    O         True
# 95                       95                       CD   NP   B    O         True
# CI                       CI                       NN   NP   I    O         True
# 8.0-13.8                 8.0-13.8                 CD   NP   I    O         True
# Ipilimumab-induced       Ipilimumab-induced       JJ   NP   B    O         False
# adverse                  adverse                  JJ   NP   I    O         False
# events                   event                    NNS  NP   I    O         False
# and                      and                      CC   O    O    O         False
# immune-related           immune-related           JJ   NP   B    O         False
# adverse                  adverse                  JJ   NP   I    O         False
# events                   event                    NNS  NP   I    O         False
# skin                     skin                     NN   NP   B    O         True
# gastrointestinal         gastrointestinal         JJ   NP   B    O         True
# hepatic                  hepatic                  JJ   NP   I    O         True
# other                    other                    JJ   NP   I    O         True
# also                     also                     RB   ADVP B    O         False
# occurred                 occur                    VBD  VP   B    O         False
# at                       at                       IN   PP   B    O         False
# similar                  similar                  JJ   NP   B    O         False
# frequencies              frequency                NNS  NP   I    O         False
# among                    among                    IN   PP   B    O         False
# patients                 patient                  NNS  NP   B    O         False
# in                       in                       IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# phase                    phase                    NN   NP   I    O         False
# II                       II                       CD   NP   I    O         False
# and                      and                      CC   NP   I    O         False
# III                      III                      CD   NP   I    O         False
# trials                   trial                    NNS  NP   I    O         False
# regardless               regardless               RB   ADVP B    O         False
# of                       of                       IN   PP   B    O         False
# HLA-A*0201               HLA-A*0201               NN   NP   B    O         False
# status.                  status.                  NNS  NP   I    O         False
# These                    These                    DT   NP   B    O         False
# findings                 finding                  NNS  NP   I    O         False
# support                  support                  VBP  VP   B    O         False
# the                      the                      DT   NP   B    O         False
# hypothesis               hypothesis               NN   NP   I    O         False
# that                     that                     IN   SBAR B    O         False
# ipilimumab-treated       ipilimumab-treated       JJ   NP   B    O         False
# patients                 patient                  NNS  NP   I    O         False
# with                     with                     IN   PP   B    O         False
# advanced                 advance                  VBN  NP   B    O         False
# melanoma                 melanoma                 NN   NP   I    O         False
# have                     have                     VBP  VP   B    O         False
# similar                  similar                  JJ   NP   B    O         False
# outcomes                 outcome                  NNS  NP   I    O         False
# regardless               regardless               RB   ADVP B    O         False
# of                       of                       IN   PP   B    O         False
# their                    their                    PRP$ NP   B    O         False
# HLA-A*0201               HLA-A*0201               NN   NP   I    protein   False
# status                   status                   NN   NP   I    O         False
# 1: Monitoring of CA19-9 and SPan- Monitoring               Monitoring               NN   NP   B    O         False
# of                       of                       IN   PP   B    O         False
# CA19-9                   CA19-9                   NN   NP   B    protein   False
# and                      and                      CC   NP   I    O         False
# SPan-1                   SPan-1                   NN   NP   I    protein   False
# can                      can                      MD   VP   B    O         False
# facilitate               facilitate               VB   VP   I    O         False
# the                      the                      DT   NP   B    O         False
# earlier                  early                    JJR  NP   I    O         False
# confirmation             confirmation             NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# progressing              progress                 VBG  VP   B    O         False
# pancreatic               pancreatic               JJ   NP   B    O         False
# cancer                   cancer                   NN   NP   I    O         False
# during                   during                   IN   PP   B    O         False
# chemotherapy.            chemotherapy.            NN   NP   B    O         False
# BACKGROUND               BACKGROUND               NN   NP   I    O         False
# Measurement              Measurement              NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# objective                objective                JJ   NP   B    O         False
# response                 response                 NN   NP   I    O         False
# to                       to                       TO   PP   B    O         False
# chemotherapy             chemotherapy             NN   NP   B    O         False
# using                    use                      VBG  VP   B    O         False
# imaging                  image                    VBG  NP   B    O         False
# modalities               modality                 NNS  NP   I    O         False
# is                       be                       VBZ  VP   B    O         False
# sometimes                sometimes                RB   ADJP B    O         False
# difficult                difficult                JJ   ADJP I    O         False
# in                       in                       IN   PP   B    O         False
# pancreatic               pancreatic               JJ   NP   B    O         False
# cancer                   cancer                   NN   NP   I    O         False
# PC                       PC                       NN   NP   B    O         True
# We                       We                       PRP  NP   B    O         False
# aimed                    aim                      VBD  VP   B    O         False
# to                       to                       TO   VP   I    O         False
# verify                   verify                   VB   VP   I    O         False
# whether                  whether                  IN   SBAR B    O         False
# monitoring               monitoring               NN   NP   B    O         False
# of                       of                       IN   PP   B    O         False
# serum                    serum                    NN   NP   B    protein   False
# tumor                    tumor                    NN   NP   I    protein   False
# markers                  marker                   NNS  NP   I    protein   False
# TMs                      TM                       NNS  NP   B    protein   True
# namely                   namely                   RB   NP   B    O         False
# carcinoembryonic         carcinoembryonic         JJ   NP   I    protein   False
# antigen                  antigen                  NN   NP   I    protein   False
# CA19-9                   CA19-9                   NN   NP   B    protein   False
# DUPAN-2                  DUPAN-2                  NN   NP   B    protein   False
# SPan-1                   SPan-1                   NN   NP   B    protein   False
# can                      can                      MD   VP   B    O         False
# facilitate               facilitate               VB   VP   I    O         False
# earlier                  early                    JJR  NP   B    O         False
# confirmation             confirmation             NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# treatment                treatment                NN   NP   B    O         False
# failure.                 failure.                 NN   NP   I    O         False
# METHODS                  METHODS                  NNS  NP   I    O         False
# Monitoring               Monitor                  VBG  VP   B    O         False
# of                       of                       IN   PP   B    O         False
# serum                    serum                    NN   NP   B    O         False
# TMs                      TM                       NNS  NP   I    O         False
# and                      and                      CC   O    O    O         False
# computed                 compute                  VBN  NP   B    O         False
# tomography               tomography               NN   NP   I    O         False
# were                     be                       VBD  VP   B    O         False
# performed                perform                  VBN  VP   I    O         False
# every                    every                    DT   NP   B    O         False
# 4                        4                        CD   NP   I    O         False
# weeks                    week                     NNS  NP   I    O         False
# until                    until                    IN   PP   B    O         False
# progression              progression              NN   NP   B    O         False
# of                       of                       IN   PP   B    O         False
# disease                  disease                  NN   NP   B    O         False
# in                       in                       IN   PP   B    O         False
# 90                       90                       CD   NP   B    O         False
# patients                 patient                  NNS  NP   I    O         False
# with                     with                     IN   PP   B    O         False
# PC                       PC                       NN   NP   B    O         False
# undergoing               undergo                  VBG  VP   B    O         False
# gemcitabine              gemcitabine              NN   NP   B    O         False
# therapy.                 therapy.                 RB   ADVP B    O         False
# In                       In                       IN   PP   B    O         False
# Group                    Group                    NN   NP   B    O         False
# A                        A                        NN   NP   I    O         False
# January                  January                  NNP  NP   B    O         True
# 2006-October             2006-October             NNP  NP   I    O         True
# 2007                     2007                     CD   NP   I    O         True
# we                       we                       PRP  NP   B    O         False
# analyzed                 analyze                  VBD  VP   B    O         False
# the                      the                      DT   NP   B    O         False
# fluctuation              fluctuation              NN   NP   I    O         False
# rates                    rate                     NNS  NP   I    O         False
# of                       of                       IN   PP   B    O         False
# TMs                      TM                       NNS  NP   B    protein   False
# with                     with                     IN   PP   B    O         False
# high                     high                     JJ   NP   B    O         False
# pretreatment             pretreatment             NN   NP   I    O         False
# positive                 positive                 JJ   NP   I    O         False
# rates                    rate                     NNS  NP   I    O         False
# and                      and                      CC   O    O    O         False
# defined                  define                   VBD  VP   B    O         False
# the                      the                      DT   NP   B    O         False
# criteria                 criterion                NNS  NP   I    O         False
# of                       of                       IN   PP   B    O         False
# progressive              progressive              JJ   NP   B    O         False
# disease                  disease                  NN   NP   I    O         False
# under                    under                    IN   PP   B    O         False
# TM                       TM                       NN   NP   B    O         False
# monitoring               monitoring               NN   NP   I    O         False
# TM-PD                    TM-PD                    NN   NP   B    protein   True
# In                       In                       IN   PP   B    O         False
# Group                    Group                    NNP  NP   B    O         False
# B                        B                        NNP  NP   I    O         False
# November                 November                 NNP  NP   B    O         True
# 2007-October             2007-October             NNP  NP   I    O         True
# 2008                     2008                     CD   NP   I    O         True
# we                       we                       PRP  NP   B    O         False
# calculated               calculate                VBD  VP   B    O         False
# the                      the                      DT   NP   B    O         False
# time                     time                     NN   NP   I    O         False
# to                       to                       TO   PP   B    O         False
# progression              progression              NN   NP   B    O         False
# TTP                      TTP                      NN   NP   B    protein   True
# under                    under                    IN   PP   B    O         False
# this                     this                     DT   NP   B    O         False
# TM-PD                    TM-PD                    NN   NP   I    O         False
# criteria                 criterion                NNS  NP   I    O         False
# which                    which                    WDT  NP   B    O         False
# was                      be                       VBD  VP   B    O         False
# compared                 compare                  VBN  VP   I    O         False
# with                     with                     IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# TTP                      TTP                      NN   NP   I    protein   False
# under                    under                    IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# RECIST                   RECIST                   NN   NP   I    O         False
# criteria.                criteria.                NN   NP   I    O         False
# RESULTS                  RESULTS                  NNS  NP   I    O         False
# CA19-9                   CA19-9                   NN   NP   I    O         False
# and                      and                      CC   NP   I    O         False
# SPan-1                   SPan-1                   NN   NP   I    protein   False
# had                      have                     VBD  VP   B    O         False
# the                      the                      DT   NP   B    O         False
# highest                  high                     JJS  NP   I    O         False
# pretreatment             pretreatment             NN   NP   I    O         False
# positive                 positive                 JJ   NP   I    O         False
# rates                    rate                     NNS  NP   I    O         False
# 83                       83                       CD   NP   B    O         False
# and                      and                      CC   O    O    O         False
# 90                       90                       CD   NP   B    O         False
# respectively.            respectively.            NN   NP   B    O         False
# In                       In                       IN   PP   B    O         False
# Group                    Group                    NN   NP   B    O         False
# A                        A                        NN   NP   I    O         False
# CA19-9                   CA19-9                   NN   NP   B    O         True
# n = 38                 n = 38                 NN   NP   B    protein   True
# SPan-1                   SPan-1                   NN   NP   B    protein   True
# n = 36                 n = 36                 NN   NP   I    protein   True
# TM-PD                    TM-PD                    NN   NP   B    O         False
# criteria                 criterion                NNS  NP   I    O         False
# were                     be                       VBD  VP   B    O         False
# defined                  define                   VBN  VP   I    O         False
# as                       as                       IN   SBAR B    O         False
# follows                  follow                   VBZ  VP   B    O         False
# fluctuation              fluctuation              NN   NP   B    O         False
# rates                    rate                     NNS  NP   I    O         False
# were                     be                       VBD  VP   B    O         False
# ≥25                    ≥25                    CD   NP   B    O         False
# for                      for                      IN   PP   B    O         False
# a                        a                        DT   NP   B    O         False
# month                    month                    NN   NP   I    O         False
# or                       or                       CC   O    O    O         False
# ≥10                    ≥10                    CD   NP   B    O         False
# for                      for                      IN   PP   B    O         False
# 2                        2                        CD   NP   B    O         False
# consecutive              consecutive              JJ   NP   I    O         False
# months                   month                    NNS  NP   I    O         False
# in                       in                       IN   PP   B    O         False
# CA19-9                   CA19-9                   NN   NP   B    O         False
# and                      and                      CC   O    O    O         False
# ≥10                    ≥10                    CD   NP   B    O         False
# for                      for                      IN   PP   B    O         False
# a                        a                        DT   NP   B    O         False
# month                    month                    NN   NP   I    O         False
# in                       in                       IN   PP   B    O         False
# SPan-1.                  SPan-1.                  NN   NP   B    O         False
# In                       In                       IN   PP   B    O         False
# Group                    Group                    NN   NP   B    O         False
# B                        B                        NN   NP   I    O         False
# CA19-9                   CA19-9                   NN   NP   B    O         True
# n = 18                 n = 18                 NN   NP   B    protein   True
# SPan-1                   SPan-1                   NN   NP   B    protein   True
# n = 17                 n = 17                 NN   NP   I    protein   True
# under                    under                    IN   PP   B    O         False
# these                    these                    DT   NP   B    O         False
# criteria                 criterion                NNS  NP   I    O         False
# one-month                one-month                JJ   NP   B    O         False
# earlier                  early                    JJR  NP   I    O         False
# confirmation             confirmation             NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# treatment                treatment                NN   NP   B    O         False
# failure                  failure                  NN   NP   I    O         False
# was                      be                       VBD  VP   B    O         False
# feasible                 feasible                 JJ   ADJP B    O         False
# in                       in                       IN   PP   B    O         False
# 61                       61                       CD   NP   B    O         False
# by                       by                       IN   PP   B    O         False
# CA19-9                   CA19-9                   NN   NP   B    O         False
# and                      and                      CC   O    O    O         False
# 59                       59                       CD   NP   B    O         False
# by                       by                       IN   PP   B    O         False
# SPan-1.                  SPan-1.                  NN   NP   B    protein   False
# Furthermore              Furthermore              RB   ADVP B    O         False
# the                      the                      DT   NP   B    O         False
# combination              combination              NN   NP   I    O         False
# could                    could                    MD   VP   B    O         False
# facilitate               facilitate               VB   VP   I    O         False
# this                     this                     DT   NP   B    O         False
# determination            determination            NN   NP   I    O         False
# in                       in                       IN   PP   B    O         False
# 72                       72                       CD   NP   B    O         False
# 35/49                    35/49                    CD   NP   B    O         True
# significantly            significantly            RB   ADJP B    O         False
# better                   good                     JJR  ADJP I    O         False
# than                     than                     IN   PP   B    O         False
# CA19-9                   CA19-9                   NN   NP   B    protein   False
# alone                    alone                    RB   ADVP B    O         False
# P = 0.004              P = 0.004              NN   NP   B    O         True
# CONCLUSION               CONCLUSION               NN   NP   B    O         False
# Monitoring               Monitoring               NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# serum                    serum                    NN   NP   B    protein   False
# CA19-9                   CA19-9                   NN   NP   I    protein   False
# and                      and                      CC   NP   I    O         False
# SPan-1                   SPan-1                   NN   NP   I    protein   False
# is                       be                       VBZ  VP   B    O         False
# helpful                  helpful                  JJ   ADJP B    O         False
# for                      for                      IN   PP   B    O         False
# earlier                  early                    JJR  NP   B    O         False
# confirmation             confirmation             NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# treatment                treatment                NN   NP   B    O         False
# failure                  failure                  NN   NP   I    O         False
# during                   during                   IN   PP   B    O         False
# gemcitabine              gemcitabine              NN   NP   B    O         False
# therapy                  therapy                  NN   NP   I    O         False
# in                       in                       IN   PP   B    O         False
# PC                       PC                       NN   NP   B    cell_type False
# 2: Improved survival with early i Improved                 Improve                  VBN  NP   B    O         False
# survival                 survival                 NN   NP   I    O         False
# with                     with                     IN   PP   B    O         False
# early                    early                    JJ   NP   B    O         False
# intensification          intensification          NN   NP   I    O         False
# combined                 combine                  VBN  NP   B    O         False
# results                  result                   NNS  NP   I    O         False
# from                     from                     IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# Medical                  Medical                  NNP  NP   I    O         False
# Research                 Research                 NNP  NP   I    O         False
# Council                  Council                  NNP  NP   I    O         False
# childhood                childhood                NN   NP   I    O         False
# ALL                      ALL                      NN   NP   I    O         False
# randomised               randomise                VBD  VP   B    O         False
# trials                   trial                    NNS  NP   B    O         False
# UKALL                    UKALL                    NNP  NP   B    O         False
# X                        X                        NNP  NP   I    O         False
# and                      and                      CC   O    O    O         False
# UKALL                    UKALL                    NNP  NP   B    O         False
# XI.                      XI.                      NNP  NP   I    O         False
# Medical                  Medical                  NNP  NP   I    O         False
# Research                 Research                 NNP  NP   I    O         False
# Council                  Council                  NNP  NP   I    O         False
# Working                  Working                  NNP  NP   I    O         False
# Party                    Party                    NNP  NP   I    O         False
# on                       on                       IN   PP   B    O         False
# Childhood                Childhood                NNP  NP   B    O         False
# Leukaemia.               Leukaemia.               NNP  NP   I    O         False
# The                      The                      NNP  NP   I    O         False
# Medical                  Medical                  NNP  NP   I    O         False
# Research                 Research                 NNP  NP   I    O         False
# Council                  Council                  NNP  NP   I    O         False
# MRC                      MRC                      NNP  NP   B    O         True
# United                   United                   NNP  NP   B    O         False
# Kingdom                  Kingdom                  NNP  NP   I    O         False
# trial                    trial                    NN   NP   I    O         False
# for                      for                      IN   PP   B    O         False
# childhood                childhood                NN   NP   B    O         False
# acute                    acute                    JJ   NP   I    O         False
# lymphoblastic            lymphoblastic            JJ   NP   I    O         False
# leukaemia                leukaemia                NN   NP   I    O         False
# UKALL                    UKALL                    NN   NP   B    O         True
# X                        X                        NN   NP   I    O         True
# randomised               randomise                VBD  VP   B    O         False
# patients                 patient                  NNS  NP   B    O         False
# aged                     age                      VBN  VP   B    O         False
# 0-14                     0-14                     CD   NP   B    O         False
# years                    year                     NNS  NP   I    O         False
# inclusive                inclusive                JJ   ADJP B    O         False
# with                     with                     IN   PP   B    O         False
# an                       an                       DT   NP   B    O         False
# initial                  initial                  JJ   NP   I    O         False
# white                    white                    JJ   NP   I    O         False
# blood                    blood                    NN   NP   I    O         False
# count                    count                    NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# less                     less                     JJR  NP   B    O         False
# than                     than                     IN   NP   I    O         False
# 100                      100                      CD   NP   I    O         False
# x                        x                        SYM  NP   I    O         False
# 10                       10                       CD   NP   I    O         False
# 9                        9                        CD   NP   B    O         True
# /l                       /l                       VBP  VP   B    O         False
# to                       to                       TO   VP   I    O         False
# receive                  receive                  VB   VP   I    O         False
# an                       an                       DT   NP   B    O         False
# early                    early                    JJ   NP   I    protein   False
# intensification          intensification          NN   NP   I    protein   False
# block                    block                    NN   NP   I    protein   False
# a                        a                        DT   NP   B    O         False
# late                     late                     JJ   NP   I    O         False
# intensification          intensification          NN   NP   I    O         False
# block                    block                    NN   NP   I    O         False
# both                     both                     CC   O    O    O         False
# or                       or                       CC   O    O    O         False
# neither.                 neither.                 RB   ADVP B    O         False
# The                      The                      DT   NP   B    O         False
# next                     next                     JJ   NP   I    O         False
# trial                    trial                    NN   NP   I    O         False
# UKALL                    UKALL                    NNP  NP   B    O         False
# XI                       XI                       NNP  NP   I    O         False
# for                      for                      IN   PP   B    O         False
# children                 child                    NNS  NP   B    O         False
# aged                     age                      VBN  VP   B    O         False
# 1-14                     1-14                     CD   NP   B    O         False
# years                    year                     NNS  NP   I    O         False
# randomised               randomise                VBN  VP   B    O         False
# between                  between                  IN   PP   B    O         False
# different                different                JJ   NP   B    O         False
# central                  central                  JJ   NP   I    O         False
# nervous                  nervous                  JJ   NP   I    O         False
# system                   system                   NN   NP   I    O         False
# CNS                      CNS                      NN   NP   B    protein   True
# directed                 direct                   VBN  VP   B    O         False
# therapies.               therapies.               RB   ADVP B    O         False
# At                       At                       IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# beginning                beginning                NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# trial                    trial                    NN   NP   I    O         False
# all                      all                      DT   NP   B    O         False
# patients                 patient                  NNS  NP   I    O         False
# were                     be                       VBD  VP   B    O         False
# also                     also                     RB   VP   I    O         False
# randomised               randomise                VBN  VP   I    O         False
# between                  between                  IN   PP   B    O         False
# late                     late                     JJ   NP   B    O         False
# intensification          intensification          NN   NP   I    O         False
# alone                    alone                    RB   ADVP B    O         False
# and                      and                      CC   O    O    O         False
# both                     both                     DT   ADJP B    O         False
# early                    early                    JJ   ADVP B    O         False
# plus                     plus                     CC   O    O    O         False
# late                     late                     JJ   NP   B    O         False
# blocks.                  blocks.                  NNS  NP   I    O         False
# The                      The                      DT   NP   B    O         False
# effects                  effect                   NNS  NP   I    O         False
# of                       of                       IN   PP   B    O         False
# both                     both                     CC   O    O    O         False
# the                      the                      DT   NP   B    O         False
# early                    early                    JJ   NP   I    O         False
# and                      and                      CC   O    O    O         False
# the                      the                      DT   NP   B    O         False
# late                     late                     JJ   NP   I    O         False
# block                    block                    NN   NP   I    O         False
# in                       in                       IN   PP   B    O         False
# UKALL                    UKALL                    NN   NP   B    O         False
# X                        X                        NN   NP   I    O         False
# alone                    alone                    RB   ADVP B    O         False
# have                     have                     VBP  VP   B    O         False
# been                     be                       VBN  VP   I    O         False
# reported                 report                   VBN  VP   I    O         False
# previously.              previously.              RB   ADVP B    O         False
# This                     This                     DT   NP   B    O         False
# paper                    paper                    NN   NP   I    O         False
# examines                 examine                  VBZ  VP   B    O         False
# the                      the                      DT   NP   B    O         False
# effect                   effect                   NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# addition                 addition                 NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# early                    early                    JJ   NP   I    O         False
# intensification          intensification          NN   NP   I    O         False
# block                    block                    NN   NP   I    O         False
# to                       to                       TO   PP   B    O         False
# treatment                treatment                NN   NP   B    O         False
# which                    which                    WDT  NP   B    O         False
# included                 include                  VBD  VP   B    O         False
# late                     late                     JJ   NP   B    O         False
# intensification          intensification          NN   NP   I    O         False
# combining                combine                  VBG  VP   B    O         False
# the                      the                      DT   NP   B    O         False
# data                     datum                    NNS  NP   I    O         False
# from                     from                     IN   PP   B    O         False
# UKALL                    UKALL                    NN   NP   B    DNA       False
# X                        X                        NN   NP   I    DNA       False
# and                      and                      CC   O    O    O         False
# the                      the                      DT   NP   B    O         False
# first                    first                    JJ   NP   I    O         False
# part                     part                     NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# UKALL                    UKALL                    NNP  NP   B    O         False
# XI.                      XI.                      NNP  NP   I    O         False
# Early                    Early                    NNP  NP   I    O         False
# intensification          intensification          NN   NP   I    O         False
# was                      be                       VBD  VP   B    O         False
# associated               associate                VBN  VP   I    O         False
# with                     with                     IN   PP   B    O         False
# fewer                    few                      JJR  NP   B    O         False
# bone                     bone                     NN   NP   I    O         False
# marrow                   marrow                   NN   NP   I    O         False
# relapses                 relapse                  NNS  NP   I    O         False
# and                      and                      CC   O    O    O         False
# a                        a                        DT   NP   B    O         False
# reduction                reduction                NN   NP   I    O         False
# in                       in                       IN   PP   B    O         False
# the                      the                      DT   NP   B    O         False
# odds                     odd                      NNS  NP   I    O         False
# of                       of                       IN   PP   B    O         False
# death                    death                    NN   NP   B    O         False
# of                       of                       IN   PP   B    O         False
# 0.63                     0.63                     CD   NP   B    O         False
# 95                       95                       CD   NP   B    O         True
# confidence               confidence               NN   NP   I    O         True
# interval                 interval                 NN   NP   I    O         True
# 0.46-0.87                0.46-0.87                CD   NP   B    O         True
# Survival                 Survival                 NN   NP   B    O         False
# was                      be                       VBD  VP   B    O         False
# significantly            significantly            RB   VP   I    O         False
# improved                 improve                  VBN  VP   I    O         False
# with                     with                     IN   PP   B    O         False
# an                       an                       DT   NP   B    O         False
# increase                 increase                 NN   NP   I    O         False
# at                       at                       IN   PP   B    O         False
# 5                        5                        CD   NP   B    O         False
# years                    year                     NNS  NP   I    O         False
# of                       of                       IN   PP   B    O         False
# 8                        8                        CD   NP   B    O         False
# from                     from                     IN   PP   B    O         False
# 79                       79                       CD   NP   B    O         False
# to                       to                       TO   PP   B    O         False
# 87                       87                       CD   NP   B    O         False
# Following                Follow                   VBG  VP   B    O         False
# this                     this                     DT   NP   B    O         False
# demonstration            demonstration            NN   NP   I    O         False
# that                     that                     IN   NP   B    O         False
# early                    early                    JJ   NP   B    O         False
# intensification          intensification          NN   NP   I    O         False
# improves                 improve                  VBZ  VP   B    O         False
# survival                 survival                 NN   NP   B    O         False
# the                      the                      DT   NP   B    O         False
# effect                   effect                   NN   NP   I    O         False
# of                       of                       IN   PP   B    O         False
# a                        a                        DT   NP   B    O         False
# third                    third                    JJ   NP   I    O         False
# intensification          intensification          NN   NP   I    O         False
# block                    block                    NN   NP   I    O         False
# is                       be                       VBZ  VP   B    O         False
# under                    under                    IN   PP   B    O         False
# investigation            investigation            NN   NP   B    O         False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-b69642f513a4> in <module>()
#       1 lengths = [len(words) for words in word_array]
#       2
# ----> 3 all_features = abstracts2features(abstracts, lengths)
#
# <ipython-input-22-1cd01b481b0c> in abstracts2features(abstract_list, length_list)
#      34         '''Step 1: Clean up genia tags'''
#      35
# ---> 36         cleaned_tags = clean_tags(genia_tags, length_list[i])
#      37
#      38         '''Step 2: Get features from these tags'''
#
# <ipython-input-21-1a07b0d831ef> in clean_tags(genia_tags, length)
#      69     if len(cleaned_tags) != length:
#      70         raise ValueError('There are ' + str(len(cleaned_tags)) +
# ---> 71                          ' tags but there should be ' + str(length))
#      72
#      73     return cleaned_tags
#
# ValueError: There are 224 tags but there should be 222
